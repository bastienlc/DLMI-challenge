# %%
# !rm -f -R ./challenge
# !git clone https://bastienlc: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@github.com/bastienlc/DLMI-challenge challenge
# %cd challenge
# !git checkout master & git pull

# %%
# %pip install -r requirements.txt

# %%
import os
from src.config import CONFIG

# This will overwrite the default paths everywhere because constant class attributes are shared between all instances
CONFIG.PATH_INPUT = "/kaggle/input/dmli-challenge/"
CONFIG.PATH_TRS = os.path.join(CONFIG.PATH_INPUT, "trainset")
CONFIG.PATH_TRS_AN = os.path.join(CONFIG.PATH_TRS, "trainset_true.csv")
CONFIG.PATH_TS = os.path.join(CONFIG.PATH_INPUT, "testset")
CONFIG.PATH_TS_AN = os.path.join(CONFIG.PATH_TS, "testset_data.csv")
CONFIG.PATH_AN = os.path.join(CONFIG.PATH_INPUT, "clinical_annotation.csv")
CONFIG.PATH_SUB = os.path.join(CONFIG.PATH_INPUT, "sample_submission.csv")

# %%
# %load main.py
